# %%
# подключение необходимых библиотек
import pandas as pd
import matplotlib.pyplot as plt

# %%
# загрузка данных
df = pd.read_csv("heart.csv")

# %%
# отображение первых 5 строк из датасета
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# вывод основных статистических показателей
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
# проверка на отсутствующие значения
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# и для работы с матрицами
import numpy as np

# %%
# построение столбцовой диаграммы здоровые/больные
c_list = [(df["target"]==0).sum(), (df["target"]==1).sum()] # value_counts
l_list = ["Здоровые", "Больные"]

plt.bar(l_list, c_list, color=(0, 1, 0))

plt.show()

# %%
# фильтрация данных по условию здоровый/больной
thalach_h = df["thalach"].where(df["target"]==0)
age_h = df["age"].where(df["target"]==0)
thalach_uh = df["thalach"].where(df["target"]==1)
age_uh = df["age"].where(df["target"]==1)

# %%
# визуализация - диаграмма рассеяния
plt.scatter(thalach_h, age_h, color="blue", marker=".")
plt.scatter(thalach_uh, age_uh, color="red", marker=".")
plt.xlabel("thalach")
plt.ylabel("age")
plt.show()

# %%
# словарь для отображения категориальных переменных
sex_map = {0: "female", 1: "male"}

# %%
# замена категориальной переменной
df["sex"] = df["sex"].map(sex_map)

# %%
# отображение
df.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3       145   233    1        0      150      0      2.3
# 1   37    male   2       130   250    0        1      187      0      3.5
# 2   41  female   1       130   204    0        0      172      0      1.4
# 3   56    male   1       120   236    0        1      178      0      0.8
# 4   57  female   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
# ввод фиктивных переменных для подстановки
df = pd.get_dummies(df, columns=["sex"], dtype="int")

# %%
# отображение первых 5 строк
df.head()
# Out:
#    age  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63   3       145   233    1        0      150      0      2.3      0   0
# 1   37   2       130   250    0        1      187      0      3.5      0   0
# 2   41   1       130   204    0        0      172      0      1.4      2   0
# 3   56   1       120   236    0        1      178      0      0.8      2   0
# 4   57   0       120   354    0        1      163      1      0.6      2   0
#
#    thal  target  sex_female  sex_male
# 0     1       1           0         1
# 1     2       1           0         1
# 2     2       1           1         0
# 3     2       1           0         1
# 4     2       1           1         0

# %%
df["chol"].where(df["target"] == 0).mean().item()
# Out:
# 251.08695652173913

# %%
df["chol"].where(df["target"] == 1).mean().item()
# Out:
# 242.23030303030302

# %%
# нормализация
features = ["age", "trestbps", "chol", "thalach"]

for column in features:
    df[column] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())

df.describe()
# Out:
#               age          cp    trestbps        chol         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528465    0.966997    0.354941    0.274575    0.148515    0.528053
# std      0.189210    1.032052    0.165454    0.118335    0.356198    0.525860
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.385417    0.000000    0.245283    0.194064    0.000000    0.000000
# 50%      0.541667    1.000000    0.339623    0.260274    0.000000    1.000000
# 75%      0.666667    2.000000    0.433962    0.339041    0.000000    1.000000
# max      1.000000    3.000000    1.000000    1.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.600358    0.326733    1.039604    1.399340    0.729373    2.313531
# std      0.174849    0.469794    1.161075    0.616226    1.022606    0.612277
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.477099    0.000000    0.000000    1.000000    0.000000    2.000000
# 50%      0.625954    0.000000    0.800000    1.000000    0.000000    2.000000
# 75%      0.725191    1.000000    1.600000    2.000000    1.000000    3.000000
# max      1.000000    1.000000    6.200000    2.000000    4.000000    3.000000
#
#            target  sex_female    sex_male
# count  303.000000  303.000000  303.000000
# mean     0.544554    0.316832    0.683168
# std      0.498835    0.466011    0.466011
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    1.000000
# 75%      1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000
